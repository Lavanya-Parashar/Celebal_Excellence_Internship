# %% [markdown]
# # **ASSIGNMENT 1**

# %% [markdown]
# **OBJECTIVE:**
# Learn Python basics and perform basic data exploration and cleaning using Pandas.

# %% [markdown]
# 1. Load a CSV Dataset (tshirts.csv) into a pandas Dataframe

# %%
#import pandas
import pandas as pd

# %%
#upload file using colab code
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-31bf4ac3-430f-482e-813a-db54e0c095d7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-31bf4ac3-430f-482e-813a-db54e0c095d7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#load dataset
df = pd.read_csv('Combined_dataset.csv')

# %% [markdown]
# 2. Data Exploration

# %%
#displaying first 5 rows of the dataset
df.head()
# Out:
#    product_id           title                         product_description  \
# 0     8376765     Lino Perros              Women Navy Blue Solid Backpack
# 1     9136281  Tommy Hilfiger           Unisex Navy Blue Striped Backpack
# 2    17633752           Lavie              Aries Women Pink Mini Backpack
# 3     1376949          F Gear  Unisex Navy & Grey Printed Burner Backpack
# 4    13939916       MYTRIDENT                    Men Blue Solid Bath Robe
#
#    rating  ratings_count  initial_price  discount  final_price currency  \
# 0     3.8             15           3995      58.0  "₹3,995.00"      INR
# 1     4.5             67           2899      35.0  "₹2,899.00"      INR
# 2     4.4            226           2999      65.0  "₹2,999.00"      INR
# 3     4.4           1052           1675      52.0  "₹1,675.00"      INR
# 4     4.7             12           2899      17.0  "₹2,899.00"      INR
#
#                                               images  ...  \
# ...

# %%
#Shape of dataset
print("Shape of dataset: ", df.shape)
# Out:
# Shape of dataset:  (1000, 24)

# %%
#Column names
print("Columns in dataset: ")
print(df.columns)
# Out:
# Columns in dataset:
# Index(['product_id', 'title', 'product_description', 'rating', 'ratings_count',
#        'initial_price', 'discount', 'final_price', 'currency', 'images',
#        'delivery_options', 'product_details', 'breadcrumbs',
#        'product_specifications', 'amount_of_stars', 'what_customers_said',
#        'seller_name', 'sizes', 'videos', 'seller_information', 'variations',
#        'best_offer', 'more_offers', 'category'],
#       dtype='object')

# %%
#Data Type of Column
print("Data Types: ")
print(df.dtypes)
# Out:
# Data Types:
# product_id                  int64
# title                      object
# product_description        object
# rating                    float64
# ratings_count               int64
# initial_price               int64
# discount                  float64
# final_price                object
# currency                   object
# images                     object
# delivery_options           object
# product_details            object
# breadcrumbs                object
# product_specifications     object
# amount_of_stars            object
# what_customers_said        object
# seller_name                object
# sizes                      object
# videos                     object
# seller_information         object
# variations                 object
# best_offer                 object
# more_offers                object
# category                   object
# dtype: object

# %% [markdown]
# 3. Handle missing values

# %%
#check missing values
print("Missing values: ")
print(df.isnull().sum())
# Out:
# Missing values:
# product_id                  0
# title                       0
# product_description         0
# rating                      0
# ratings_count               0
# initial_price               0
# discount                  121
# final_price                 0
# currency                    0
# images                      0
# delivery_options            0
# product_details             0
# breadcrumbs                 0
# product_specifications      0
# amount_of_stars             0
# what_customers_said       573
# seller_name               301
# sizes                       0
# videos                    781
# seller_information        301
# variations                562
# best_offer                  0
# more_offers                 0
# category                    0
# dtype: int64

# %%
#handling missing values according to specific columns
#for cleaner dataset

df['discount'] = df['discount'].fillna(0)

df['what_customers_said'] = df['what_customers_said'].fillna("No Review")

df['seller_name'] = df['seller_name'].fillna("Unknown Seller")

df['videos'] = df['videos'].fillna("No video")

df['seller_information'] = df['seller_information'].fillna("Not available")

df['variations'] = df['variations'].fillna("No variations")

print("Missing values handled successfully! ")
# Out:
# Missing values handled successfully!

# %% [markdown]
# 4. Remove Duplicates

# %%
#remove duplicates
df.drop_duplicates(inplace=True)
print("Duplicates removed successfully! ")
# Out:
# Duplicates removed successfully!

# %% [markdown]
# 5. Perform basic operations

# %%
#displaying products with rating greater than 10
high_rating = df[df['rating']>4]
high_rating.head()
# Out:
#    product_id           title                         product_description  \
# 1     9136281  Tommy Hilfiger           Unisex Navy Blue Striped Backpack
# 2    17633752           Lavie              Aries Women Pink Mini Backpack
# 3     1376949          F Gear  Unisex Navy & Grey Printed Burner Backpack
# 4    13939916       MYTRIDENT                    Men Blue Solid Bath Robe
# 5    17198778             H&M  Beige & Tan Solid Stoneware Soap Dispenser
#
#    rating  ratings_count  initial_price  discount  final_price currency  \
# 1     4.5             67           2899      35.0  "₹2,899.00"      INR
# 2     4.4            226           2999      65.0  "₹2,999.00"      INR
# 3     4.4           1052           1675      52.0  "₹1,675.00"      INR
# 4     4.7             12           2899      17.0  "₹2,899.00"      INR
# 5     4.5             42           1399       0.0  "₹1,399.00"      INR
#
#                                               images  ...  \
# ...

# %%
#selecting particular columns
selected_columns = df[['title', 'rating', 'final_price']]
selected_columns.head()
# Out:
#             title  rating  final_price
# 0     Lino Perros     3.8  "₹3,995.00"
# 1  Tommy Hilfiger     4.5  "₹2,899.00"
# 2           Lavie     4.4  "₹2,999.00"
# 3          F Gear     4.4  "₹1,675.00"
# 4       MYTRIDENT     4.7  "₹2,899.00"

# %% [markdown]
# 6. Create Derived Coulmn

# %%
# Clean final_price column
df['final_price'] = (
    df['final_price']
    .astype(str)
    .str.replace('₹', '', regex=False)
    .str.replace(',', '', regex=False)
    .str.replace('"', '', regex=False)
    .str.strip()
)

# Convert to float
df['final_price'] = pd.to_numeric(df['final_price'])

# Create derived column
# here : final_price acts as price
# ratings_count act as quantity
df['total_amount'] = df['final_price'] * df['ratings_count']

# Check result
df[['final_price', 'ratings_count', 'total_amount']].head()
# Out:
#    final_price  ratings_count  total_amount
# 0       3995.0             15       59925.0
# 1       2899.0             67      194233.0
# 2       2999.0            226      677774.0
# 3       1675.0           1052     1762100.0
# 4       2899.0             12       34788.0

# %%
#view updated dataset
df.head()
# Out:
#    product_id           title                         product_description  \
# 0     8376765     Lino Perros              Women Navy Blue Solid Backpack
# 1     9136281  Tommy Hilfiger           Unisex Navy Blue Striped Backpack
# 2    17633752           Lavie              Aries Women Pink Mini Backpack
# 3     1376949          F Gear  Unisex Navy & Grey Printed Burner Backpack
# 4    13939916       MYTRIDENT                    Men Blue Solid Bath Robe
#
#    rating  ratings_count  initial_price  discount  final_price currency  \
# 0     3.8             15           3995      58.0       3995.0      INR
# 1     4.5             67           2899      35.0       2899.0      INR
# 2     4.4            226           2999      65.0       2999.0      INR
# 3     4.4           1052           1675      52.0       1675.0      INR
# 4     4.7             12           2899      17.0       2899.0      INR
#
#                                               images  ... what_customers_said  \
# ...

# %% [markdown]
# 7. Saving the cleaned dataset

# %%
df.to_csv('cleaned_Combined_dataset.csv',index=False)
print("Cleaned dataset saved successfully! ")
# Out:
# Cleaned dataset saved successfully!

# %% [markdown]
# ------------Assignment 1 Completed-----------------
